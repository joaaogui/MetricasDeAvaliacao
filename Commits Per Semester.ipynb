# %%
from github import Github
import plotly.plotly as py
import plotly
from plotly.graph_objs import *
import plotly.graph_objs as go
from collections import defaultdict
import pandas as pd
import numpy as np

# %%
# Create a Github instance:
g = Github("9324fedffc85017817ff2533e9237fc81fc611a9")

# Find the organization I want
org = g.get_organization("fga-gpp-mds")

# Get all repos from my account, including from organizations
repos = org.get_repos()

# %%
repo_list = list()
amount = list()

# %%
repo_commits_x = {'2016.1-Partiu_backend': 85, '2016.1-Partiu_frontend': 403, '2016.1-avalia_mais': 379, '2016.1-AbasteceAqui': 547, '2016.1-Emergo': 343, '2016.1-TemRemedioAi': 346, '2016.1-Purrsuit_front': 45, '2016.1-elugar': 302, '2016.1-Purrsuit_back': 178, '2016.2-WikiLegis': 758, '2016.2-MissaoNascente': 491, '2016.2-Owla': 520, '2016.2-Observatorio-de-Residuos-Frontend': 687, '2016.2-SAS_FGA': 1302, '2016.2-Jardim-Botanico-Web': 1118, '2016.2-SME_UnB': 406, '2016.2-CidadeDemocratica': 442, '2016.2-SAAP': 372, '2016.2-CidadeDemocratica-api': 79, '2016.2-Observatorio-de-Residuos-Backend': 294, '2017.1-PlataformaJogosUnB': 1004, '2017.1-Trezentos': 405, '2017.1-Forum-Coordenadores-DEG': 406, '2017.1-Escola-X': 832, '2017.1-SIGS': 921, '2017.1-Cadernos-API': 342, '2017.1-OndeE-UnB': 651, '2017.1-Trezentos-RestAPI': 78, '2017.1-DEG-API': 73, '2017.1-Cadernos-APP': 420, '2017.1-PlataformaJogosUnB-FrontEnd': 8, '2017.1-Escola-X.app': 87, '2017.2-AjudaConselheiro-Backend': 26, '2017.2-Receita-Mais': 1022, '2017.2-MerendaMais': 1002, '2017.2-Classificacao-de-Risco-Pediatrico': 1047, '2017.2-DepuTinder': 556, '2017.2-QueroCultura': 1208, '2017.2-SiGI-Op_API': 342, '2017.2-fisCAE': 634, '2017.2-SiGI-Op': 425, '2017.2-AjudaConselheiro-Frontend': 783, '2017.2-MerendaMais-Backend': 17, '2017.2-DepuTinder-API': 221, '2017.2-Falko-FrontEnd': 807, '2017.2-Falko-BackEnd': 656, '2018.1-Reabilitacao-Motora': 1118, '2018.1-Cardinals': 616, '2018.1-TropicalHazards-BI': 651, '2018.1_Nexte': 1824, '2018.1-Dr-Down': 1863, '2018.1_Gerencia_mais': 861, '2018.1-VoxPop-WebApp': 660, '2018.1-Lacos-da-Alegria': 636, '2018.1-IncluCare_API': 224, '2018.1-VoxPop-API': 191, '2018.1-Lacos-da-Alegria-API': 235, '2018.1-TropicalHazards-BI-FrontEnd': 461, '2018.1-IncluCare': 283, '2018.1-Reabilitacao-Motora-Launcher': 35, '2018.1-Dulce_App': 3036, '2018.1-Reabilitacao-Motora-Spatium-API': 16, '2018.1-Reabilitacao-Motora-UDP-App-Android': 7}

repo_commits = {'2016.1-Partiu_backend': 85, '2016.1-Partiu_frontend': 403, '2016.1-avalia_mais': 379, '2016.1-AbasteceAqui': 547, '2016.1-Emergo': 343, '2016.1-TemRemedioAi': 346, '2016.1-Purrsuit_front': 45, '2016.1-elugar': 302, '2016.1-Purrsuit_back': 178, '2016.2-WikiLegis': 758, '2016.2-MissaoNascente': 491, '2016.2-Owla': 520, '2016.2-Observatorio-de-Residuos-Frontend': 687, '2016.2-SAS_FGA': 1302, '2016.2-Jardim-Botanico
'TropicalHazards': 1112,
'Nexte': 1824,
'Dr-Down': 1863,
'Gerencia_mais': 861,
'VoxPop': 851,
'Lacos-da-Alegria': 871,
'IncluCare': 507,
'Dulce': 3032}

# %%
repo_dict = defaultdict(list)
for repo in repo_commits:
    print(repo)
    name = str(repo[:6])
    print(name)
    repo_dict[name].append(repo_commits[repo])
print(repo_dict)
# Out:
# 2016.1-Partiu_backend
# 2016.1
# 2016.1-Partiu_frontend
# 2016.1
# 2016.1-avalia_mais
# 2016.1
# 2016.1-AbasteceAqui
# 2016.1
# 2016.1-Emergo
# 2016.1
# 2016.1-TemRemedioAi
# 2016.1
# 2016.1-Purrsuit_front
# 2016.1
# 2016.1-elugar
# 2016.1
# 2016.1-Purrsuit_back
# 2016.1
# 2016.2-WikiLegis
# 2016.2
# 2016.2-MissaoNascente
# 2016.2
# 2016.2-Owla
# 2016.2
# 2016.2-Observatorio-de-Residuos-Frontend
# 2016.2
# 2016.2-SAS_FGA
# 2016.2
# 2016.2-Jardim-Botanico-Web
# 2016.2
# 2016.2-SME_UnB
# 2016.2
# 2016.2-CidadeDemocratica
# 2016.2
# 2016.2-SAAP
# 2016.2
# 2016.2-CidadeDemocratica-api
# 2016.2
# 2016.2-Observatorio-de-Residuos-Backend
# 2016.2
# 2017.1-PlataformaJogosUnB
# 2017.1
# 2017.1-Trezentos
# 2017.1
# 2017.1-Forum-Coordenadores-DEG
# 2017.1
# 2017.1-Escola-X
# 2017.1
# 2017.1-SIGS
# 2017.1
# 2017.1-Cadernos-API
# 2017.1
# 2017.1-OndeE-UnB
# 2017.1
# 2017.1-Trezentos-RestAPI
# 2017.1
# 2017.1-DEG-API
# 2017.1
# 2017.1-Cadernos-APP
# 2017.1
# 2017.1-PlataformaJogosUnB-FrontEnd
# 2017.1
# 2017.1-Escola-X.app
# 2017.1
# 2017.2-AjudaConselheiro-Backend
# 2017.2
# 2017.2-Receita-Mais
# 2017.2
# 2017.2-MerendaMais
# 2017.2
# 2017.2-Classificacao-de-Risco-Pediatrico
# 2017.2
# 2017.2-DepuTinder
# 2017.2
# 2017.2-QueroCultura
# 2017.2
# 2017.2-SiGI-Op_API
# 2017.2
# 2017.2-fisCAE
# 2017.2
# 2017.2-SiGI-Op
# 2017.2
# 2017.2-AjudaConselheiro-Frontend
# 2017.2
# 2017.2-MerendaMais-Backend
# 2017.2
# 2017.2-DepuTinder-API
# 2017.2
# 2017.2-Falko-FrontEnd
# 2017.2
# 2017.2-Falko-BackEnd
# 2017.2
# 2018.1-assdadf
# 2018.1
# 2018.1-sadsadas
# 2018.1
# 2018.1-sds
# 2018.1
# 2018.1-asdasda
# 2018.1
# 2018.1-adsada
# 2018.1
# 2018.1-asdsd
# 2018.1
# 2018.1-adsa
# 2018.1
# 2018.1-adasda
# 2018.1
# 2018.1-dasdasd
# 2018.1
# 2018.1-sadasd
# 2018.1
# defaultdict(<class 'list'>, {'2016.1': [85, 403, 379, 547, 343, 346, 45, 302, 178], '2016.2': [758, 491, 520, 687, 1302, 1118, 406, 442, 372, 79, 294], '2017.1': [1004, 405, 406, 832, 921, 342, 651, 78, 73, 420, 8, 87], '2017.2': [26, 1022, 1002, 1047, 556, 1208, 342, 634, 425, 783, 17, 221, 807, 656], '2018.1': [1176, 616, 1112, 1824, 1863, 861, 851, 871, 507, 3032]})

# %%
# keys = list(repo_dict.keys())
keys = list()
for key in list(repo_dict.keys()): 
    key = f'"{key}"'
    key = key.replace(".","-")
    key = str(key)
    keys.append(key)
medians = list()

for lista in repo_dict.values():
    print()
#     print(np.median(lista))
    medians.append(np.median(lista))
print(keys)
print(medians)
# Out:
# ['"2016-1"', '"2016-2"', '"2017-1"', '"2017-2"', '"2018-1"']
# [343.0, 491.0, 405.5, 645.0, 991.5]

# %%
# for repo in repo_commits:
#     if repo_commits[repo] < 51:
#         print(repo, repo_commits[repo])

# %%
# for idx, repo in enumerate(list(repo_commits.keys())):
#     if repo[:3] == "201":
#         name = repo[:6]
#         name = f'"{name}"'
#         name = name.replace(".","-")
#         name = str(name)
#         repo_list.append(name)
# amount = list(repo_commits.values())
# print(repo_list)

# %%
# values = list(repo_commits.values())
# print(values)

# %%
# Setting up plotly
plotly.tools.set_credentials_file(username='joaaogui', api_key='2TfVhKWEO6rpuxlj7c6R')
# Setting the privacy of the chart
plotly.tools.set_config_file(world_readable=True, sharing='public')

trace1 = {
  "x": keys, 
  "y": medians, 
#   "mode": "lines", 
#   "type": "scatter"
}

data = Data([trace1])
layout = {
    "title": "Mediana de commit por tempo",
  "xaxis": {"title": "Semestre"}, 
  "yaxis": {
    "title": "Quantidade De Commits", 
    "zeroline": False
  }
}

fig = Figure(data=data, layout=layout)
py.iplot(fig, filename = 'Mediana de commit por tempo')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~joaaogui/130.embed" height="525px" width="100%"></iframe>

# %%
# # Setting up plotly
# plotly.tools.set_credentials_file(username='joaaogui', api_key='2TfVhKWEO6rpuxlj7c6R')
# # Setting the privacy of the chart
# plotly.tools.set_config_file(world_readable=True, sharing='public')

# maxLine = max(values) + 100

# trace1 = {
#   "x": values,
#   "autobinx": False, 
#   "marker": {"line": {"width": 1}}, 
#   "nbinsx": 0, 
#   "type": "histogram", 
#   "uid": "27cccf", 
#   "xbins": {
#     "end": maxLine, 
#     "size": 50, 
#     "start": 0
#   }
# }

# data = Data([trace1])

# layout = {
#   "autosize": True, 
#   "bargroupgap": 0, 
#   "title": "Grupos por quantidade de commits - 2018.1", 
#   "xaxis": {
#     "autorange": False, 
#     "dtick": 50, 
#     "fixedrange": True, 
#     "range": [0, maxLine], 
#     "showgrid": False, 
#     "showline": False, 
#     "showticklabels": True, 
#     "tick0": 0, 
#     "tickmode": "linear", 
#     "title": "Quantidade de Commits", 
#     "type": "linear", 
#     "zeroline": False
#   }, 
#   "yaxis": {
#     "autorange": True,  
#     "title": "Quantidade De Grupos", 
#     "zeroline": False,
#       "dtick": 1
#   }
# }
# fig = Figure(data=data, layout=layout)
# py.iplot(fig, filename = 'Grupos por quantidade de commits')

# %%
# # Setting up plotly
# plotly.tools.set_credentials_file(username='joaaogui', api_key='2TfVhKWEO6rpuxlj7c6R')
# # Setting the privacy of the chart
# plotly.tools.set_config_file(world_readable=True, sharing='public')
# # py.sign_in('username', 'api_key')
# trace1 = {
#   "x": repo_list,
#   "y": amount, 
#   "mode": "markers", 
# #   "type": "scatter", 
# }
# data = Data([trace1])
# layout = {
#     "title": "Commits por semestre",
#   "xaxis": {"title": "Semestre"}, 
#   "yaxis": {
#     "title": "Quantidade De Commits", 
#     "zeroline": False
#   }
# }
# fig = Figure(data=data, layout=layout)
# py.iplot(fig, filename = 'Commit per semmester')
